# %% [markdown]
# # Exploring Player Behavior and Preferences on Steam: An Interactive Analysis

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Data Import & Merging

# %%
data_dir = "data"

dfs = {
    filename[:-4]: pd.read_csv(os.path.join(data_dir, filename))
    for filename in os.listdir(data_dir)
    if filename.endswith(".csv")
}

# %%
for name, df in dfs.items():
    print(f"{name} - shape: {df.shape}")
# Out:
# purchased_games - shape: (102548, 2)
# reviews - shape: (1204534, 8)
# history - shape: (10693879, 3)
# friends - shape: (424683, 2)
# prices - shape: (4414273, 7)
# players - shape: (424683, 3)
# games - shape: (98248, 7)
# private_steamids - shape: (227963, 1)
# achievements - shape: (1939027, 4)

# %%
achievements = dfs['achievements']
games = dfs['games']
history = dfs['history']
players = dfs['players']
prices = dfs['prices']
purchased_games = dfs['purchased_games']
reviews = dfs['reviews']
friends = dfs['friends']
private_steamids = dfs['private_steamids']

# %% [markdown]
# ## Section I (Yufeng)

# %% [markdown]
# ## Section II (Jiaxuan)

# %% [markdown]
# ## Section III (Serena)
